# %% [markdown]
# # **Creating a Word Cloud of the novel "*Alice's Adventure in the Wonderland*" by Lewis Corrol Using wordcloud module.**

# %% [markdown]
# Import important data analysis modules.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# Let's try to analyze a short novel written by **Lewis Corrol** titled *Alice's Adventures in the Wonderland.* Let's go ahead and download a *.txt* file of the novel.

# %%
import urllib

# open the file and read it into a variable alice_novel
alice_novel = urllib.request.urlopen('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/alice_novel.txt').read().decode("utf-8")

# %% [markdown]
# Now use the STOPWORDS, that we have imported from word_cloud. We use the function *set* to to remove any redundant words.

# %%
stopwords = set(STOPWORDS)

# %% [markdown]
# Create a word cloud object and generate a word cloud. Let's generate a word cloud using the first 2000 words in the novel.

# %%
# instantiate a word cloud onject
alice_wc = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)

# generate the word cloud
alice_wc.generate(alice_novel)

# %% [markdown]
# Word cloud is create now let's visualize it.

# %%
# import matplotlib

# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Let's visualize

plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Save mask to alice_mask

# %%
alice_mask = np.array(Image.open(urllib.request.urlopen('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%204/images/alice_mask.png')))

# %%
fig = plt.figure(figsize=(14,8))

plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Shaping the word cloud according to the mask is done by using wordcloud package. We will continue with using the first 2000 words of the novel.

# %%
alice_wc = WordCloud(background_color='white', max_words=2000, mask=alice_mask, stopwords=stopwords)

# generate the word cloud
alice_wc.generate(alice_novel)

fig = plt.figure(figsize=(14, 8))
plt.imshow(alice_wc, interpolation='bilinear')
plt.axis('off')
plt.show()
